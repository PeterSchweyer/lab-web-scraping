# %% [markdown]
# # Lab | Web Scraping

# %% [markdown]
# Welcome to the IMDb Web Scraping Adventure Lab!
#
# **Objective**
#
# In this lab, we will embark on a mission to unearth valuable insights from the vast sea of data available on IMDb, one of the largest online databases of movie, TV, and celebrity information. As budding data scientists and business analysts, you have been tasked to scrape a specific subset of data from IMDb to assist film production companies in understanding the landscape of highly-rated movies in a defined time period. Your insights will potentially influence the making of the next netflix movie!
#
# **Background**
#
# In a world where data has become the new currency, businesses are leveraging big data to make informed decisions that drive success and profitability. The entertainment industry, being no exception, utilizes data analytics to comprehend market trends, audience preferences, and the performance of films based on various parameters such as director, genre, stars involved, etc. IMDb stands as a goldmine of such data, offering intricate details of almost every movie ever made.
#
# **Task**
#
# Your task is to create a Python script using `BeautifulSoup` and `pandas` to scrape IMDb movie data based on user ratings and release dates. This script should be able to filter movies with ratings above a certain threshold and within a specified date range.
#
# **Expected Outcome**
#
# - A function named `scrape_imdb` that takes four parameters: `title_type`,`user_rating`, `start_date`, and `end_date`.
# - The function should return a DataFrame with the following columns:
#   - **Movie Nr**: The number representing the movie’s position in the list.
#   - **Title**: The title of the movie.
#   - **Year**: The year the movie was released.
#   - **Rating**: The IMDb rating of the movie.
#   - **Runtime (min)**: The duration of the movie in minutes.
#   - **Genre**: The genre of the movie.
#   - **Description**: A brief description of the movie.
#   - **Director**: The director of the movie.
#   - **Stars**: The main stars of the movie.
#   - **Votes**: The number of votes the movie received.
#   - **Gross ($M)**: The gross earnings of the movie in millions of USD.
#
# You will execute this script to scrape data for movies with the Title Type `Feature Film` that have a user rating of `7.5 and above` and were released between `January 1, 1990, and December 31, 1992`.
#
# Remember to experiment with different title types, dates and ratings to ensure your code is versatile and can handle various searches effectively!
#
# **Resources**
#
# - [Beautiful Soup Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Pandas Documentation](https://pandas.pydata.org/pandas-docs/stable/index.html)
# - [IMDb Advanced Search](https://www.imdb.com/search/title/)

# %% [markdown]
# **Hint**
#
# Your first mission is to familiarize yourself with the IMDb advanced search page. Head over to [IMDb advanced search](https://www.imdb.com/search/title/) and input the following parameters, keeping all other fields to their default values or blank:
#
# - **Title Type**: Feature film
# - **Release date**: From 1990 to 1992 (Note: You don't need to specify the day and month)
# - **User Rating**: 7.5 to -
#
# Upon searching, you'll land on a page showcasing a list of movies, each displaying vital details such as the title, release year, and crew information. Your task is to scrape this treasure trove of data.
#
# Carefully examine the resulting URL and construct your own URL to include all the necessary parameters for filtering the movies.

# %% [markdown]
# ---
#
# **Best of luck! Immerse yourself in the world of movies and may the data be with you!**

# %% [markdown]
# **Important note**:
#
# In the fast-changing online world, websites often get updates and make changes. When you try this lab, the IMDb website might be different from what we expect.
#
# If you run into problems because of these changes, like new rules or things that stop you from getting data, don't worry! Instead, get creative.
#
# You can choose another website that interests you and is good for scraping data. Websites like Wikipedia or The New York Times are good options. The main goal is still the same: get useful data and learn how to scrape it from a website that you find interesting. It's a chance to practice your web scraping skills and explore a source of information you like.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
#title_type,user_rating, start_date, and end_date
#title_type =

def scrape_imdb(title_type, start_date, end_date, user_rating):
  url = f"https://www.imdb.com/search/title/?title_type={title_type}&release_date={start_date},{end_date}&user_rating={user_rating},&start=101&ref_=adv_nxt"
  response = requests.get(url)
  soup = BeautifulSoup(response.content)

  film_dict = {}
  index = 0

  films = soup.find_all("div", attrs = {"class":"lister-item mode-advanced"})
  for film in films:
    #getting the position, name and year
    film_header = film.find_all("h3", attrs = {"class":"lister-item-header"})
    for item in film_header:
      film_position = item.find_all("span", attrs = {"class":"lister-item-index unbold text-primary"})[0].get_text().strip()
      film_name = item.find_all("a")[0].get_text().strip()
      film_year = item.find_all("span", attrs = {"class":"lister-item-year text-muted unbold"})[0].get_text().strip()

    #getting more film data
    film_genre = film.find_all("span", attrs = {"class":"genre"})[0].get_text().strip()
    film_duration = film.find_all("span", attrs = {"class":"runtime"})[0].get_text().strip()
    film_rating = film.find_all("div", attrs = {"class":"inline-block ratings-imdb-rating"})[0].get_text().strip()
    film_description = film.find_all("p", attrs = {"class":"text-muted"})[1].get_text().strip()

    film_director_stars = film.find_all("p")[2] #currently this will return not only the director but also the actors!
    film_director = film_director_stars.find_all("a")[0].get_text().strip() #assuming the first position contains data regarding the director
    film_actors = ",".join([actor.get_text().strip() for actor in film_director_stars.find_all("a")[1:]]) #assuming from position 1 forward we have actors


    film_dict[index] = {"ranking":film_position,
                        "title":film_name,
                        "year":film_year,
                        "genre":film_genre,
                        "duration":film_duration,
                        "rating":film_rating,
                        "description": film_description,
                        "director":film_director,
                        "actors":film_actors}
    index +=1
  return pd.DataFrame.from_dict(film_dict, orient="index")

scrape_imdb(title_type="feature", start_date="1990-01-01", end_date="1992-12-31", user_rating="7.5")
# Out:
#    ranking                                title         year  \
# 0     101.                    Relatos Selvagens       (2014)
# 1     102.                             Brooklyn       (2015)
# 2     103.                     A Teoria de Tudo       (2014)
# 3     104.                 Um Homem Chamado Ove       (2015)
# 4     105.         Star Trek: Além da Escuridão       (2013)
# 5     106.        A Descoberta do Primeiro Amor   (I) (2010)
# 6     107.        Como Treinares o Teu Dragão 2       (2014)
# 7     108.                        Uma Separação       (2011)
# 8     109.                                   42       (2013)
# 9     110.        A Rapariga Que Roubava Livros       (2013)
# 10    111.                  Antes da Meia-Noite       (2013)
# 11    112.                     As Asas do Vento       (2013)
# 12    113.                      A Grande Beleza       (2013)
# 13    114.                                 Mamã   (I) (2014)
# 14    115.                        Temporário 12       (2013)
# 15    116.                            O Artista   (I) (2011)
# 16    117.                            El cuerpo       (2012)
# 17    118.                             Victoria  (II) (2015)
# 18    119.                  The Raid - Redenção       (2014)
# 19    120.             Ao Encontro de Mr. Banks       (2013)
# 20    121.             Eu, o Earl e a Tal Miúda       (2015)
# 21    122.                                   PK       (2014)
# 22    123.                             Drishyam       (2015)
# 23    124.           No se aceptan devoluciones       (2013)
# 24    125.                              Ajeossi       (2010)
# 25    126.                         Um Caso Real       (2012)
# 26    127.                   O Meu Nome é Alice       (2014)
# 27    128.   Headhunters - Caçadores de Cabeças       (2011)
# 28    129.        Selma - A Marcha da Liberdade       (2014)
# 29    130.          O Mundo Secreto de Arrietty       (2010)
# 30    131.                             Do-ga-ni       (2011)
# 31    132.                                  Boy   (I) (2010)
# 32    133.                   Gangs of Wasseypur       (2012)
# 33    134.                             Filomena       (2013)
# 34    135.                              Orgulho   (I) (2014)
# 35    136.  Fruitvale Station: A Última Paragem       (2013)
# 36    137.                  Beasts of No Nation       (2015)
# 37    138.        Gokuraku sentô: Kyonyû yumomi       (2011)
# 38    139.                                 Amor       (2012)
# 39    140.                      My Name Is Khan       (2010)
# 40    141.                      Sono de Inverno       (2014)
# 41    142.    Who Am I - Kein System ist sicher       (2014)
# 42    143.                Amor de Fim de Semana  (II) (2011)
# 43    144.                       Terra de Minas       (2015)
# 44    145.                   Memórias de Marnie       (2014)
# 45    146.                             Nebraska       (2013)
# 46    147.                   Oslo, 31 de Agosto       (2011)
# 47    148.                   Ciclo Interrompido       (2012)
# 48    149.                      O Principezinho       (2015)
# 49    150.                      A Canção do Mar       (2014)
#
#                            genre duration rating  \
# 0        Comedy, Drama, Thriller  122 min    8.1
# 1                 Drama, Romance  117 min    7.5
# 2      Biography, Drama, Romance  123 min    7.7
# 3         Comedy, Drama, Romance  116 min    7.7
# 4      Action, Adventure, Sci-Fi  132 min    7.7
# 5         Comedy, Drama, Romance   90 min    7.7
# 6   Animation, Action, Adventure  102 min    7.8
# 7                          Drama  123 min    8.3
# 8        Biography, Drama, Sport  128 min    7.5
# 9                     Drama, War  131 min    7.5
# 10                Drama, Romance  109 min    7.9
# 11   Animation, Biography, Drama  126 min    7.7
# 12                         Drama  141 min    7.7
# 13                         Drama  139 min    8.0
# 14                         Drama   96 min    7.9
# 15        Comedy, Drama, Romance  100 min    7.9
# 16         Crime, Drama, Mystery  112 min    7.6
# 17         Crime, Drama, Romance  138 min    7.6
# 18       Action, Crime, Thriller  150 min    7.9
# 19      Biography, Comedy, Drama  125 min    7.5
# 20        Comedy, Drama, Romance  105 min    7.7
# 21         Comedy, Drama, Sci-Fi  153 min    8.1
# 22         Crime, Drama, Mystery  163 min    8.2
# 23                 Comedy, Drama  115 min    7.5
# 24          Action, Crime, Drama  119 min    7.7
# 25     Biography, Drama, History  137 min    7.5
# 26                         Drama  101 min    7.5
# 27       Action, Crime, Thriller  100 min    7.5
# 28     Biography, Drama, History  128 min    7.5
# 29   Animation, Adventure, Drama   94 min    7.6
# 30                         Drama  125 min    8.0
# 31                 Comedy, Drama   87 min    7.5
# 32         Action, Comedy, Crime  321 min    8.2
# 33      Biography, Comedy, Drama   98 min    7.6
# 34      Biography, Comedy, Drama  119 min    7.8
# 35       Biography, Crime, Drama   85 min    7.5
# 36                    Drama, War  137 min    7.7
# 37                        Comedy   60 min    8.5
# 38                         Drama  127 min    7.9
# 39     Adventure, Drama, Romance  165 min    7.9
# 40                         Drama  196 min    8.1
# 41         Crime, Drama, Mystery  102 min    7.5
# 42                Drama, Romance   97 min    7.6
# 43           Drama, History, War  100 min    7.8
# 44      Animation, Drama, Family  103 min    7.7
# 45                         Drama  115 min    7.7
# 46                         Drama   95 min    7.6
# 47         Drama, Music, Romance  111 min    7.7
# 48   Animation, Adventure, Drama  108 min    7.7
# 49   Animation, Adventure, Drama   93 min    8.0
#
#                                           description               director  \
# 0   Six short stories that explore the extremities...         Damián Szifron
# 1   An Irish immigrant lands in 1950s Brooklyn, wh...           John Crowley
# 2   A look at the relationship between the famous ...            James Marsh
# 3   Ove, an ill-tempered, isolated retiree who spe...            Hannes Holm
# 4   After the crew of the Enterprise find an unsto...            J.J. Abrams
# 5   Two eighth-graders start to have feelings for ...             Rob Reiner
# 6   When Hiccup and Toothless discover an ice cave...           Dean DeBlois
# 7   A married couple are faced with a difficult de...         Asghar Farhadi
# 8   In 1947, Jackie Robinson becomes the first Afr...        Brian Helgeland
# 9   While subjected to the horrors of World War II...         Brian Percival
# 10  We meet Jesse and Celine nine years on in Gree...      Richard Linklater
# 11  A look at the life of Jiro Horikoshi, the man ...         Hayao Miyazaki
# 12  Jep Gambardella has seduced his way through th...       Paolo Sorrentino
# 13  A widowed single mother, raising her violent s...           Xavier Dolan
# 14  A 20-something supervising staff member of a r...  Destin Daniel Cretton
# 15  An egomaniacal film star develops a relationsh...    Michel Hazanavicius
# 16  A detective searches for the body of a femme f...            Oriol Paulo
# 17  A young Spanish woman who has recently moved t...     Sebastian Schipper
# 18  Only a short time after the first raid, Rama g...           Gareth Evans
# 19  Author P.L. Travers reflects on her childhood ...       John Lee Hancock
# 20  High schooler Greg, who spends most of his tim...    Alfonso Gomez-Rejon
# 21  An alien on Earth loses the only device he can...        Rajkumar Hirani
# 22  Desperate measures are taken by a man who trie...        Nishikant Kamat
# 23  A man who has made a new life for himself and ...         Eugenio Derbez
# 24  A quiet pawnshop keeper with a violent past ta...         Jeong-beom Lee
# 25  A young queen, who is married to an insane kin...          Nikolaj Arcel
# 26  A linguistics professor and her family find th...        Richard Glatzer
# 27  An accomplished headhunter risks everything to...          Morten Tyldum
# 28  A chronicle of Dr. Martin Luther King, Jr.'s c...           Ava DuVernay
# 29  The Clock family are four-inch-tall people who...   Hiromasa Yonebayashi
# 30  Based on real events, this film depicts the st...        Hwang Dong-hyuk
# 31  Boy, an 11-year-old child and devout Michael J...          Taika Waititi
# 32  A clash between Sultan and Shahid Khan leads t...         Anurag Kashyap
# 33  A world-weary political journalist picks up th...         Stephen Frears
# 34  U.K. gay activists work to help miners during ...        Matthew Warchus
# 35  The story of Oscar Grant III, a 22-year-old Ba...           Ryan Coogler
# 36  A drama based on the experiences of Agu, a chi...     Cary Joji Fukunaga
# 37  Kasuko is a young woman who happens to have hu...         Yoshikazu Katô
# 38  Georges and Anne are an octogenarian couple. T...         Michael Haneke
# 39  An Indian Muslim man with Asperger's syndrome ...            Karan Johar
# 40  A hotel owner and landlord in a remote Turkish...      Nuri Bilge Ceylan
# 41  Benjamin, a young German computer whiz, is inv...          Baran bo Odar
# 42  After a drunken house party with his straight ...           Andrew Haigh
# 43  In post-World War II Denmark, a group of young...       Martin Zandvliet
# 44  Due to 12-year-old Anna's asthma, she's sent t...   Hiromasa Yonebayashi
# 45  An aging, booze-addled father makes the trip f...        Alexander Payne
# 46  One day in the life of Anders, a young recover...          Joachim Trier
# 47  Elise and Didier fall in love at first sight, ...   Felix van Groeningen
# 48  A little girl lives in a very grown-up world w...           Mark Osborne
# 49  Ben, a young Irish boy, and his little sister ...             Tomm Moore
#
#                                                actors
# 0   Darío Grandinetti,María Marull,Mónica Villa,Di...
# 1   Saoirse Ronan,Emory Cohen,Domhnall Gleeson,Jim...
# 2   Eddie Redmayne,Felicity Jones,Tom Prior,Sophie...
# 3     Rolf Lassgård,Bahar Pars,Filip Berg,Ida Engvoll
# 4   Chris Pine,Zachary Quinto,Zoe Saldana,Benedict...
# 5   Madeline Carroll,Callan McAuliffe,Rebecca De M...
# 6   Jay Baruchel,Cate Blanchett,Gerard Butler,Crai...
# 7   Payman Maadi,Leila Hatami,Sareh Bayat,Shahab H...
# 8   Chadwick Boseman,T.R. Knight,Harrison Ford,Nic...
# 9   Sophie Nélisse,Geoffrey Rush,Emily Watson,Ben ...
# 10  Ethan Hawke,Julie Delpy,Seamus Davey-Fitzpatri...
# 11  Hideaki Anno,Hidetoshi Nishijima,Miori Takimot...
# 12  Toni Servillo,Carlo Verdone,Sabrina Ferilli,Ca...
# 13  Anne Dorval,Antoine Olivier Pilon,Suzanne Clém...
# 14  Brie Larson,Frantz Turner,John Gallagher Jr.,K...
# 15  Jean Dujardin,Bérénice Bejo,John Goodman,James...
# 16  Jose Coronado,Hugo Silva,Belén Rueda,Aura Garrido
# 17  Laia Costa,Frederick Lau,Franz Rogowski,Burak ...
# 18     Iko Uwais,Yayan Ruhian,Arifin Putra,Oka Antara
# 19  Emma Thompson,Tom Hanks,Annie Rose Buckley,Col...
# 20    Thomas Mann,RJ Cyler,Olivia Cooke,Nick Offerman
# 21  Aamir Khan,Anushka Sharma,Sanjay Dutt,Boman Irani
# 22          Ajay Devgn,Shriya Saran,Tabu,Rajat Kapoor
# 23  Eugenio Derbez,Karla Souza,Jessica Lindsey,Lor...
# 24       Won Bin,Kim Sae-ron,Kim Tae-hoon,Kim Hee-won
# 25  Alicia Vikander,Mads Mikkelsen,Mikkel Boe Føls...
# 26  Wash Westmoreland,Julianne Moore,Alec Baldwin,...
# 27  Aksel Hennie,Synnøve Macody Lund,Nikolaj Coste...
# 28  David Oyelowo,Carmen Ejogo,Oprah Winfrey,Tom W...
# 29  Bridgit Mendler,Amy Poehler,Will Arnett,Mirai ...
# 30    Gong Yoo,Jung Yu-mi,Hyeon-soo Kim,Jee-Young Kim
# 31  James Rolleston,Te Aho Eketone-Whitu,Taika Wai...
# 32  Manoj Bajpayee,Nawazuddin Siddiqui,Tigmanshu D...
# 33  Judi Dench,Steve Coogan,Sophie Kennedy Clark,M...
# 34  Bill Nighy,Imelda Staunton,Dominic West,Paddy ...
# 35  Michael B. Jordan,Melonie Diaz,Octavia Spencer...
# 36  Abraham Attah,Emmanuel Affadzi,Ricky Adelayito...
# 37  Hitomi Tanaka,Riri Kôda,Mari Yamaguchi,Tôshi Y...
# 38  Jean-Louis Trintignant,Emmanuelle Riva,Isabell...
# 39  Shah Rukh Khan,Kajol,Sheetal Menon,Katie Amand...
# 40  Haluk Bilginer,Melisa Sözen,Demet Akbag,Ayberk...
# 41  Tom Schilling,Elyas M'Barek,Wotan Wilke Möhrin...
# 42   Tom Cullen,Chris New,Jonathan Race,Laura Freeman
# 43  Roland Møller,Louis Hofmann,Joel Basman,Mikkel...
# 44  Sara Takatsuki,Kasumi Arimura,Nanako Matsushim...
# 45     Bruce Dern,Will Forte,June Squibb,Bob Odenkirk
# 46  Anders Danielsen Lie,Hans Olav Brenner,Ingrid ...
# 47  Veerle Baetens,Johan Heldenbergh,Nell Cattryss...
# 48  Jeff Bridges,Mackenzie Foy,Rachel McAdams,Mari...
# 49  David Rawle,Brendan Gleeson,Lisa Hannigan,Fion...

# %%
"Stars: Jodie Foster, Anthony Hopkins, Lawrence A. Bonney, Kasi Lemmons".split("Stars")
# Out:
# ['', ': Jodie Foster, Anthony Hopkins, Lawrence A. Bonney, Kasi Lemmons']

# %%
n_pages = int(input("how many pages you want?"))
## 1---> 1 -------  1 + 50*(n_pages-1)
## 2--> 51  ------- 1 + 50*(n_pages-1) = 51
## 3--> 101 ------- 1 + 50*(n_pages-1) = 101


for i in range(1,n_pages+1):
  n_pages = 1 + 50*(i-1)
  url = f"https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-31-12&user_rating=7.5,&start={n_pages}&ref_=adv_nxt"
  print(url)
# Out:
# how many pages you want?5
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-31-12&user_rating=7.5,&start=1&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-31-12&user_rating=7.5,&start=51&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-31-12&user_rating=7.5,&start=101&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-31-12&user_rating=7.5,&start=151&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-31-12&user_rating=7.5,&start=201&ref_=adv_nxt

# %% [markdown]
# ## BONUS
#
# The search results span multiple pages, housing a total of 631 movies in our example with each page displaying 50 movies at most. To scrape data seamlessly from all pages, you'll need to dive deep into the structure of the URLs generated with each "Next" click.
#
# Take a close look at the following URLs:
# - First page:
#   ```
#   https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,
#   ```
# - Second page:
#   ```
#   https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=51&ref_=adv_nxt
#   ```
# - Third page:
#   ```
#   https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=101&ref_=adv_nxt
#   ```
#
# You should notice a pattern. There is a `start` parameter incrementing by 50 with each page, paired with a constant `ref_` parameter holding the value "adv_nxt".
#
# Modify your script so it's capable of iterating over all available pages to fetch data on all the 631 movies (631 is the total number of movies in the proposed example).

# %%
# Your solution goes here
